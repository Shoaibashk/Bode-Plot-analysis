# %%
import matplotlib.pyplot as plt
import numpy as np
import control

# %%
f = np.logspace(-2,3,1000) #Hz  10 rest to -2 is min & 10 reat to 3 is max 
w = 2*np.pi*f
s = 1.0j*w

# %%
p1 = 10*2*np.pi
p2 = 40*2*np.pi
p3 = 10

# %%
z = control.TransferFunction(1,1)
p = control.TransferFunction(100,[1,25*2*np.pi,100*2*np.pi,0])

G = z*p

# %%
G
# Out:
#            100
# -------------------------
# s^3 + 157.1 s^2 + 628.3 s

# %%
out = control.bode_plot(G,dB=1,Hz=1,deg=1,)
